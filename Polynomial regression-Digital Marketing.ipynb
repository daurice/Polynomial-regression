# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Read the data back from the CSV file
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/polynomial regression/ad_spend_clicks.csv')

# %%
df.head()
# Out:
#      Ad Spend  Clicks
# 0  553.325369    4069
# 1  718.037473   15666
# 2  606.735742    9848
# 3  549.434351    5295
# 4  429.418251    2802

# %%
# Plotting
plt.figure(figsize=(10, 6))
# scatter plot with s=9 of the orignal data
plt.scatter(df['Ad Spend'],df['Clicks'],color='green',label='Data Points',s=9)

# %%
X = df[['Ad Spend']].values
X
# Out:
# array([[553.32536889],
#        [718.03747271],
#        [606.73574231],
#        [549.43435117],
#        [429.41825135],
#        [649.43517194],
#        [443.21133915],
#        [892.85527077],
#        [964.0261329 ],
#        [389.60710364],
#        [793.8077877 ],
#        [533.60597056],
#        [572.36411548],
#        [926.34067191],
#        [ 80.32569762],
#        [ 30.01621347],
#        [834.29364709],
#        [780.37518344],
#        [871.31202676],
#        [978.83215881],
#        [801.16697857],
#        [466.86456863],
#        [782.72388452],
#        [643.52181111],
#        [151.91975453],
#        [945.22222788],
#        [526.62983853],
#        [420.51532059],
#        [271.91005598],
#        [776.49135254],
#        [461.58882889],
#        [572.74960938],
#        [ 28.60190243],
#        [621.45914211],
#        [615.9747655 ],
#        [620.76465691],
#        [944.31059773],
#        [685.00209611],
#        [365.91282157],
#        [700.65488397],
#        [ 69.62321691],
#        [670.09904829],
#        [673.93149092],
#        [218.27873546],
#        [137.63703468],
#        [322.27406741],
#        [370.07366323],
#        [574.49480271],
#        [444.21549833],
#        [988.49009968],
#        [111.02436264],
#        [216.78798853],
#        [656.57724221],
#        [260.75868651],
#        [471.64766513],
#        [251.98133608],
#        [167.37988781],
#        [659.76629357],
#        [146.80112184],
#        [375.03791895],
#        [822.78329755],
#        [106.13026304],
#        [839.56545842],
#        [105.13742382],
#        [976.69487036],
#        [473.96468963],
#        [976.99347731],
#        [608.79706455],
#        [741.8709436 ],
#        [289.97889295],
#        [128.9945956 ],
#        [303.17879555],
#        [127.54044176],
#        [324.8033476 ],
#        [420.12036457],
#        [695.54739818],
#        [570.93543966],
#        [272.73559603],
#        [528.01557293],
#        [103.00110565],
#        [580.1870306 ],
#        [930.0032356 ],
#        [325.38326293],
#        [670.73627616],
#        [140.47988378],
#        [719.16393208],
#        [296.51203202],
#        [191.35944839],
#        [590.64780546],
#        [ 29.90647073],
#        [830.65062893],
#        [681.03837143],
#        [277.30789346],
#        [737.8420819 ],
#        [962.56665967],
#        [580.39576107],
#        [596.12151196],
#        [576.52938673],
#        [230.85081631],
#        [953.2215214 ],
#        [452.65412483],
#        [847.94458575],
#        [702.48448256],
#        [304.46258135],
#        [815.65984151],
#        [402.54068344],
#        [882.29216514],
#        [585.46014391],
#        [882.91800824],
#        [695.60627418],
#        [728.00173702],
#        [506.31113811],
#        [956.52279838],
#        [647.55029724],
#        [429.61649807],
#        [610.32928199],
#        [663.57180212],
#        [297.17683114],
#        [621.83527471],
#        [434.48101394],
#        [144.11932358],
#        [305.2995027 ],
#        [574.26526159],
#        [594.96403364],
#        [578.58199636],
#        [656.66881166],
#        [655.5822373 ],
#        [437.10425108],
#        [897.58112989],
#        [373.88625135],
#        [893.00412147],
#        [808.13204916],
#        [706.8496977 ],
#        [109.22461844],
#        [920.28778761],
#        [717.09888655],
#        [998.8585365 ],
#        [157.95382161],
#        [869.44479679],
#        [170.86800533],
#        [619.40396864],
#        [132.58178302],
#        [849.52814703],
#        [809.24576914],
#        [573.40973123],
#        [413.11146425],
#        [ 78.4753255 ],
#        [700.45448541],
#        [724.83504348],
#        [867.71850267],
#        [975.76628995],
#        [857.24530897],
#        [ 21.59694334],
#        [366.37828383],
#        [732.6906568 ],
#        [179.91338049],
#        [525.82624014],
#        [ 63.79460846],
#        [ 28.33657652],
#        [795.76072632],
#        [231.68544118],
#        [351.89816389],
#        [928.80048053],
#        [707.3702579 ],
#        [ 41.52054024],
#        [173.04721493],
#        [625.26361748],
#        [581.45630272],
#        [245.51389316],
#        [934.87185795],
#        [617.82629641],
#        [540.27647499],
#        [594.01087659],
#        [732.82080922],
#        [318.82554552],
#        [404.23885159],
#        [194.33107582],
#        [944.92866608],
#        [742.1552871 ],
#        [495.55422053],
#        [261.81291695],
#        [ 67.44886872],
#        [440.0724593 ],
#        [318.67792317],
#        [699.38005393],
#        [383.9743209 ],
#        [ 34.43194111],
#        [ 76.57713515],
#        [682.59884576],
#        [459.15987611],
#        [541.213419  ],
#        [897.70458011],
#        [990.43555792],
#        [224.72801455],
#        [666.44742107],
#        [270.68915297],
#        [760.7948673 ],
#        [326.81697931],
#        [389.62925523],
#        [592.43394242],
#        [832.73797068],
#        [632.69202516],
#        [873.92414889],
#        [280.80661447],
#        [800.06636557],
#        [953.2637404 ],
#        [690.61339362],
#        [223.35260034],
#        [947.89688458],
#        [733.5472487 ],
#        [261.40222617],
#        [221.17885759],
#        [523.01870679],
#        [215.39537469],
#        [430.43861406],
#        [380.42828053],
#        [468.93967012],
#        [284.85241923],
#        [590.91650299],
#        [865.21704986],
#        [126.3565374 ],
#        [522.20531608],
#        [140.74742528],
#        [719.69108438],
#        [402.09910578],
#        [569.76709874],
#        [191.44703785],
#        [153.39928175],
#        [493.17571784],
#        [362.05661047],
#        [941.0276258 ],
#        [767.67200127],
#        [751.17698365],
#        [904.68254235],
#        [ 92.58821109],
#        [556.67054522],
#        [588.63130827],
#        [962.31701476],
#        [299.22605152],
#        [248.42049212],
#        [109.29100284],
#        [ 26.2653333 ],
#        [930.23402362],
#        [673.21738113],
#        [787.3013829 ],
#        [288.9128047 ],
#        [590.54606452],
#        [ 73.31571346],
#        [490.77131998],
#        [977.72018835],
#        [877.74019286],
#        [344.77736232],
#        [961.954453  ],
#        [949.82563419],
#        [941.96392766],
#        [801.21056148],
#        [634.1434575 ],
#        [875.54508696],
#        [300.09008166],
#        [850.45411976],
#        [621.697925  ],
#        [ 23.10448918],
#        [353.76118275],
#        [982.01109592],
#        [483.58660397],
#        [502.41745184],
#        [643.07779123],
#        [374.89876007],
#        [145.53126897],
#        [823.89655586],
#        [197.94943278],
#        [516.20579272],
#        [232.07385868],
#        [106.86603965],
#        [863.56960225],
#        [973.19029413],
#        [961.22631148],
#        [907.48994423],
#        [776.30685937],
#        [339.81370051],
#        [ 90.29037609],
#        [413.1687597 ],
#        [239.91180075],
#        [728.33842057],
#        [ 21.31318404],
#        [772.87494102],
#        [155.47717895],
#        [ 88.72686176],
#        [ 98.7070039 ],
#        [675.32732928],
#        [426.33407201],
#        [561.79510341],
#        [861.94566209],
#        [729.77382008],
#        [277.62462619],
#        [140.1679713 ],
#        [ 64.82057722],
#        [308.58264814],
#        [269.49696775],
#        [461.57916113],
#        [686.44852219],
#        [698.66919118],
#        [290.68365812],
#        [386.12768634],
#        [189.33945212],
#        [790.66005718],
#        [ 66.27959567],
#        [700.02726931],
#        [780.90844198],
#        [779.63348623],
#        [266.8283387 ],
#        [380.07500655],
#        [591.72363884],
#        [280.0936834 ],
#        [377.14427123],
#        [205.08373738],
#        [465.25732492],
#        [ 54.16617824],
#        [801.79792572],
#        [ 86.18688252],
#        [523.64679734],
#        [581.76751934],
#        [959.83900743],
#        [649.11454201],
#        [436.09841511],
#        [514.9166838 ],
#        [540.81571976],
#        [684.5785855 ],
#        [284.82013675],
#        [137.57195981],
#        [398.74891978],
#        [956.84166557],
#        [195.25958283],
#        [904.94411538],
#        [548.36789058],
#        [462.34230743],
#        [883.22099613],
#        [464.01792215],
#        [726.92596025],
#        [405.03506849],
#        [905.00394897],
#        [693.12476999],
#        [702.62583371],
#        [334.44319754],
#        [759.21085631],
#        [639.70044489],
#        [247.62007065],
#        [168.93343426],
#        [798.42755977],
#        [959.574937  ],
#        [463.55743899],
#        [595.07432367],
#        [859.14541775],
#        [462.65121882],
#        [952.35573206],
#        [579.99365042],
#        [822.55944949],
#        [909.75528123],
#        [817.36858058],
#        [167.82031881],
#        [632.60945467],
#        [ 72.0858225 ],
#        [429.79192937],
#        [850.54792534],
#        [ 42.97158028],
#        [959.39289464],
#        [361.81515999],
#        [ 26.16521766],
#        [193.38000198],
#        [407.2469058 ],
#        [929.99850313],
#        [945.84851814],
#        [870.79364524],
#        [459.62077294],
#        [333.43387295],
#        [240.41668799],
#        [618.32005941],
#        [ 25.4500038 ],
#        [434.50776527],
#        [ 77.39333323],
#        [259.42157836],
#        [228.94930619],
#        [260.65928179],
#        [139.7446789 ],
#        [ 21.91586067],
#        [124.32945417],
#        [622.29545692],
#        [974.51365069],
#        [990.44155155],
#        [171.32488179],
#        [642.37413979],
#        [495.40229308],
#        [989.51567951],
#        [ 74.65116508],
#        [785.40209393],
#        [295.51451236],
#        [249.00443388],
#        [665.87952582],
#        [253.60255314],
#        [669.20052638],
#        [522.13543203],
#        [429.84809855],
#        [559.14093057],
#        [294.18100472],
#        [709.50895921],
#        [420.70830064],
#        [366.94010488],
#        [830.37034541],
#        [925.71724283],
#        [ 55.54723778],
#        [240.3007229 ],
#        [355.0341758 ],
#        [816.81681458],
#        [985.63651337],
#        [969.28198762],
#        [905.89886209],
#        [303.59070241],
#        [992.09113098],
#        [256.92584065],
#        [114.84709333],
#        [951.44308494],
#        [241.08605291],
#        [692.87058243],
#        [ 67.77279539],
#        [733.40200814],
#        [882.90301021],
#        [279.71252651],
#        [385.26632712],
#        [380.55322149],
#        [751.30037496],
#        [454.7987322 ],
#        [840.79723104],
#        [245.36440776],
#        [507.36556291],
#        [943.1577637 ],
#        [637.65772077],
#        [868.61651141],
#        [940.80759246],
#        [753.25721327],
#        [702.57930962],
#        [968.28591094],
#        [994.45678175],
#        [457.30346584],
#        [ 80.1610804 ],
#        [299.86609113],
#        [423.31151105],
#        [139.97643519],
#        [608.07662598],
#        [388.97997857],
#        [896.43202545],
#        [968.11672508],
#        [551.41605265],
#        [282.07533417],
#        [596.30811457],
#        [897.79354664],
#        [556.55749393],
#        [460.88970796],
#        [407.69640003],
#        [255.92933043],
#        [510.80771999]])

# %%
y = df['Clicks'].values
y
# Out:
# array([ 4069, 15666,  9848,  5295,  2802, 10509,  1902, 49453, 75281,
#          755, 29583,  5887,  7832, 62876,   282,  1920, 37007, 24115,
#        45887, 82659, 29963,  2522, 25661, 11284,   632, 68195,  6363,
#         2825,  1539, 25768,  4467,  8153,  2115,  9479,  5917,  8884,
#        67987, 13996,  2609, 14796,  1324, 11938, 11142,  2070,  1334,
#           75,  1885,  7157,  2348, 86796,  1094,   552, 11243,  1308,
#         3892,   924,  1554, 10670,   870,  2529, 34685,  1335, 38156,
#         3425, 80222,   247, 81149,  7931, 19826,   608,  1219,   569,
#         3896,    98,  1047, 15244,  3587,   449,  3998,   148,  8530,
#        64289,  2836, 11496,  2356, 18161,  2078,  2248,  5883,   491,
#        36824, 15319,  1769, 19854, 75320,  6034,  8588,  7825,  4273,
#        71361,  1692, 39055, 14454,  1083, 33141,  1754, 49725,  6425,
#        48166, 14251, 16684,  1791, 71292, 12192,  3198,  9734, 11138,
#         1365,  9404,  3451,  1343,  3270,  5893,  6109,  4348, 10287,
#        11556,  1165, 53899,  3231, 52472, 28520, 16634,  2470, 59922,
#        15786, 89781,   690, 44755,   763,  8516,  1257, 38594, 31131,
#         7942,  1452,   467, 16752, 19669, 43770, 80594, 42014,  2131,
#         1160, 18424,  2566,  1420,  1024,    86, 31317,   985,  1621,
#        60548, 15336,  1236,  1432,  9771,  6516,  1686, 65322,  6352,
#         4798,  8075, 19962,   790,   847,   856, 69728, 18143,  2595,
#         2018,   335,  1712,   966, 15878,  1147,  1652,  1527, 13388,
#         1297,  5210, 53266, 86128,   772, 11061,   878, 23643,   126,
#         1954,  5381, 35532,  9406, 44156,  1251, 29234, 69901, 15165,
#         2106, 69300, 19833,  1344,  1425,  5710,  1837,  1677,  1319,
#         2423,   672,  5517, 44108,  3006,  4074,  1000, 16804,  1650,
#         6512,   568,   459,  3812,   350, 67260, 25177, 23369, 54800,
#         2641,  6629,  5673, 73495,   794,  2292,   913,   279, 65037,
#        13122, 24626,  1513,  7593,  1271,  3808, 81133, 45587,   902,
#        73680, 68659, 67837, 30018,  9103, 45801,  1135, 41558,  6391,
#         1452,   743, 80696,  2004,  3829, 10762,   417,  2223, 36068,
#         1491,  3247,  2388,  1907, 44512, 78544, 71127, 58311, 23634,
#         1278,  3857,  2311,  2186, 18046,  2309, 24598,    50,  1238,
#         2298, 11236,  1133,  6916, 43344, 21425,  2230,   960,  2518,
#         1444,   244,  3459, 13189, 14920,  2730,  1516,    48, 27438,
#         2226, 14749, 25862, 25501,  1306,  1123,  5109,    47,   442,
#         2511,  3688,  1705, 29403,    21,  3578,  9518, 71293, 11428,
#         2092,  2733,  3360, 12474,  3228,   842,   838, 73496,  1027,
#        55852,  2867,  3021, 49594,   695, 19047,  3858, 54989, 15679,
#        16496,   445, 22953,  8160,   514,  1325, 30256, 73914,  3544,
#         5887, 42244,  2686, 73342,  6177, 33484, 56501, 31921,  1237,
#         9095,   930,  1746, 40205,  2787, 74440,  2184,  1572,  1191,
#         2481, 63601, 68655, 44416,  2546,   212,  2622,  7548,  1090,
#          901,   490,    77,  2729,  2018,   933,   531,  2130,  9321,
#        80475, 86664,   871,  9599,  4157, 87501,   210, 27647,  3233,
#          256, 14147,    41, 12446,  4126,  2141,  4485,   437, 15648,
#         2398,  1881, 38400, 63289,   388,  1437,  2603, 32950, 84507,
#        77798, 56321,   156, 87036,  1633,  1374, 71067,   604, 15834,
#         3561, 19817, 48347,  2017,   983,   690, 21794,  2102, 36788,
#          529,  1730, 67237,  9250, 44790, 68263, 22242, 15711, 77453,
#        88759,  1344,   862,  1533,  3078,  2299,  7191,  1373, 51382,
#        78104,  3902,   849,  6247, 52899,  6975,  2702,  1596,   153,
#         2733])

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Simple linear regression
simple_model = LinearRegression()
simple_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict using simple linear regression
y_pred_simple_fit = simple_model.predict(X_test)

# %%
y_pred_simple_fit
# Out:
# array([ -9744.86745601,   6692.65931506,  31888.55073555,  18304.73899912,
#           636.30576838,   2152.38585422, -18096.93878668, -10550.58734548,
#          9469.77631707, -14361.05878784,  31152.24540482,  29686.61778248,
#         13796.16439465,  34345.597689  ,  21490.75388991,  -9558.369078  ,
#         28249.73164497, -14759.26397093,  50611.67669657, -14449.41458662,
#          9258.85572386, -17471.71009245,  40196.10320071,   4325.92125325,
#         21304.18329392,  25044.77936384,  13391.23251847,  31955.97909496,
#         37399.34516658,  17887.32810404,  22881.54885543,  13911.62934805,
#         28208.9338504 ,  22659.39473936,   1254.73078764, -17968.25079538,
#         42529.41166937,  45387.71649124,  23210.89920386,   1601.78105501,
#         15972.70402853, -17741.17464279,  10054.10355384,  29582.70602432,
#         -9173.0678875 ,  36472.65163435,  39480.95598246,   6733.02073666,
#         14255.24868227,  21388.11731675,  12890.74606883,   4398.43148676,
#         25077.83901553,  21565.87129272,  34913.88945031,  21937.44863853,
#         16821.23501846,  -7603.45542755, -11377.42985437,   8111.46333553,
#         33008.66899245,  21627.33289502,  49295.03747273, -17154.48266602,
#         12212.37302519,  -2955.817812  , -10696.21371785,  30848.80153008,
#         30340.28423255,  51644.09026849,  48042.93435609,  28447.51569882,
#          9412.57581557,  26892.15562425,  24756.77295294,  36142.07232162,
#         41475.57660589,  40046.14783481,  -2392.73729812,  17068.5207929 ,
#          8363.01727575,   7314.77054706,  11248.3179081 ,   8316.37301191,
#         10782.76237713,  14421.70453731,  30838.64681421,  30564.5549398 ,
#         -1525.65763592,  48469.16006771,  48854.71687679,  22431.57717692])

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics as w
mae=w.mean_absolute_error(y_test,y_pred_simple_fit)
print(f"Mean Absolute Error:{mae}")
mse=w.mean_squared_error(y_test,y_pred_simple_fit)
print(f"Mean Squared Error:{mse}")
r2=w.r2_score(y_test,y_pred_simple_fit)
print(f"R^2 Score:{r2}")
# Out:
# Mean Absolute Error:12431.872252730396
# Mean Squared Error:194289122.5415304
# R^2 Score:0.4982121298153428

# %%
# Plotting
plt.figure(figsize=(10, 6))

# Original data points
plt.scatter(X_test, y_test, color='blue', label='Test Data Points',s=3)
plt.scatter(X_train, y_train, color='red', label='Train Data Points',s=3)


# Simple linear regression line
plt.plot(X_test, y_pred_simple_fit, color='green', label='Simple Linear Regression')


plt.title('Simple Regression Model')
plt.xlabel('Ad Spend ($)')
plt.ylabel('Clicks')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Polynomial regression
degree = 4
poly_features = PolynomialFeatures(degree=degree)
X_poly = poly_features.fit_transform(X)
X_poly
# Out:
# array([[1.00000000e+00, 5.53325369e+02, 3.06168964e+05, 1.69411055e+08,
#         9.37394344e+10],
#        [1.00000000e+00, 7.18037473e+02, 5.15577812e+05, 3.70204189e+08,
#         2.65820480e+11],
#        [1.00000000e+00, 6.06735742e+02, 3.68128261e+05, 2.23356574e+08,
#         1.35518417e+11],
#        ...,
#        [1.00000000e+00, 4.07696400e+02, 1.66216355e+05, 6.77658094e+07,
#         2.76278765e+10],
#        [1.00000000e+00, 2.55929330e+02, 6.54998222e+04, 1.67633256e+07,
#         4.29022671e+09],
#        [1.00000000e+00, 5.10807720e+02, 2.60924527e+05, 1.33282263e+08,
#         6.80816087e+10]])

# %%
# Split the data into training and testing sets
X_train_poly, X_test_poly, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=0)

# %%
#Polynomial regression model
poly_model = LinearRegression()
poly_model.fit(X_train_poly,  y_train)
# Out:
# LinearRegression()

# %%
y_pred_poly_fit = poly_model.predict(X_test_poly)
y_pred_poly_fit
# Out:
# array([ 2.09521788e+03, -3.73199781e+03,  2.34370785e+04,  3.36094786e+03,
#        -3.74873065e+03, -3.98143585e+03,  1.21815528e+04,  2.85898867e+03,
#        -2.88006682e+03,  7.07642919e+03,  2.20233028e+04,  1.93202248e+04,
#        -4.95204380e+02,  2.84248689e+04,  6.92961426e+03,  1.92479781e+03,
#         1.68136862e+04,  7.57484075e+03,  7.19261103e+04,  7.18607711e+03,
#        -2.96339821e+03,  1.12602376e+04,  4.19740527e+04, -4.03906207e+03,
#         6.70137688e+03,  1.17348807e+04, -7.73066161e+02,  2.35684124e+04,
#         3.52031158e+04,  2.94516862e+03,  8.70651492e+03, -4.13905110e+02,
#         1.67445924e+04,  8.41375266e+03, -3.86275852e+03,  1.19897236e+04,
#         4.80349309e+04,  5.59702056e+04,  9.14679514e+03, -3.91521771e+03,
#         1.19169141e+03,  1.16540119e+04, -2.63321617e+03,  1.91341917e+04,
#         1.58029618e+03,  3.30783450e+04,  4.01914525e+04, -3.72341768e+03,
#        -1.66532558e+02,  6.80375940e+03, -1.10090169e+03, -4.03537962e+03,
#         1.17836607e+04,  7.02218412e+03,  2.96376669e+04,  7.48580450e+03,
#         1.93767227e+03,  2.82491476e+02,  3.68923840e+03, -3.36307815e+03,
#         2.56593744e+04,  7.09821436e+03,  6.77275577e+04,  1.08030715e+04,
#        -1.51773693e+03, -2.56587672e+03,  3.00180104e+03,  2.14515202e+04,
#         2.05075253e+04,  7.53017760e+04,  6.38454910e+04,  1.71502712e+04,
#        -2.90296844e+03,  1.45760588e+04,  1.13131058e+04,  3.23346796e+04,
#         4.52511411e+04,  4.15973521e+04, -2.80999238e+03,  2.16439787e+03,
#        -3.28320796e+03, -3.58729270e+03, -2.05562061e+03, -3.29834679e+03,
#        -2.29246661e+03, -4.37784882e+01,  2.14324951e+04,  2.09216602e+04,
#        -3.14322566e+03,  6.51548625e+04,  6.63500700e+04,  8.11705486e+03])

# %%
print(f"Test R2: {r2_score(y_test, y_pred_poly_fit)}")
# Out:
# Test R2: 0.9298043510934413

# %%
# Plotting
plt.figure(figsize=(10, 6))

# Original data points
plt.scatter(X_test, y_test, color='blue', label='Data Points',s=3)
plt.scatter(X_train, y_train, color='red', label='Data Points',s=3)


# Simple linear regression line
plt.plot(X_test, y_pred_poly_fit, color='green', label='Polynomial Regression')

plt.title('Simple Regression Model')
plt.xlabel('Ad Spend ($)')
plt.ylabel('Clicks')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #Irregular vs smooth curve presetation of the polynomial curve
#
# X_test points may be sparse and irregular, leading to a less smooth and potentially misleading representation of the regression curve.
#
# X_test contains only the test data points, which may not cover the entire range of 'Ad Spend' values, especially if the dataset is small or unevenly distributed.
#
# Create X_fit instead of X_test for plotting the polynomial regression model provides a more comprehensive visualization of the regression curve across the entire range of the independent variable.
#
# X_fit is generated using np.linspace, which creates evenly spaced values from the minimum to the maximum of 'Ad Spend'. This ensures that the plot covers the entire range of the independent variable.

# %%
"""
np.linspace(start, stop, num):

np.linspace is a function from the NumPy library.
It generates num evenly spaced values between start and stop.
"""

X_fit = np.linspace(df['Ad Spend'].min(), df['Ad Spend'].max(), 10)
X_fit
# Out:
# array([ 21.31318404, 129.92933431, 238.54548459, 347.16163486,
#        455.77778513, 564.39393541, 673.01008568, 781.62623595,
#        890.24238623, 998.8585365 ])

# %%
"""
X_fit:

X_fit is a 1-dimensional array of values. In this context, it likely contains evenly spaced values of ad spend created by the np.linspace function.
X_fit[:, np.newaxis]:

This operation reshapes X_fit from a 1-dimensional array to a 2-dimensional array with a single column.
np.newaxis is used to add a new axis, converting the shape of X_fit from (10,) to (10, 1).
This is necessary because many machine learning algorithms expect a 2-dimensional array as input.
"""

X_fit_poly = poly_features.transform(X_fit[:, np.newaxis])
X_fit_poly
# Out:
# array([[1.00000000e+00, 2.13131840e+01, 4.54251814e+02],
#        [1.00000000e+00, 1.29929334e+02, 1.68816319e+04],
#        [1.00000000e+00, 2.38545485e+02, 5.69039482e+04],
#        [1.00000000e+00, 3.47161635e+02, 1.20521201e+05],
#        [1.00000000e+00, 4.55777785e+02, 2.07733389e+05],
#        [1.00000000e+00, 5.64393935e+02, 3.18540514e+05],
#        [1.00000000e+00, 6.73010086e+02, 4.52942575e+05],
#        [1.00000000e+00, 7.81626236e+02, 6.10939573e+05],
#        [1.00000000e+00, 8.90242386e+02, 7.92531506e+05],
#        [1.00000000e+00, 9.98858537e+02, 9.97718376e+05]])

# %%
Y_fit_poly = poly_model.predict(X_fit_poly)
Y_fit_poly
# Out:
# array([12181.55284862,  2610.83107912, -2769.00850052, -3957.96589032,
#         -956.04109027,  6236.76589963, 17620.45507937, 33195.02644896,
#        52960.4800084 , 76916.81575768])

# %%
df_poly_fit = pd.DataFrame({'Ad Spend': X_fit, 'Clicks': Y_fit_poly})
df_poly_fit
# Out:
#      Ad Spend        Clicks
# 0   21.313184  12181.552849
# 1  129.929334   2610.831079
# 2  238.545485  -2769.008501
# 3  347.161635  -3957.965890
# 4  455.777785   -956.041090
# 5  564.393935   6236.765900
# 6  673.010086  17620.455079
# 7  781.626236  33195.026449
# 8  890.242386  52960.480008
# 9  998.858537  76916.815758

# %%
# Plotting
plt.figure(figsize=(10, 6))

# Original data points
plt.scatter(X_test, y_test, color='blue', label='Data Points',s=3)
plt.scatter(X_train, y_train, color='red', label='Data Points',s=3)

# Simple linear regression line
plt.plot(X_test, y_pred_simple_fit, color='green', label='Simple Linear Regression')

# Polynomial regression curve
plt.plot(df_poly_fit['Ad Spend'], df_poly_fit['Clicks'], color='orange', label=f'Polynomial Regression (Degree {degree})')

plt.title('Simple and Polynomial Regression Models')
plt.xlabel('Ad Spend ($)')
plt.ylabel('Clicks')
plt.legend()
plt.grid(True)
plt.show()
